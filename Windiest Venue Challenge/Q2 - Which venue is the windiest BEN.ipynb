# %%
import pandas as pd
games=pd.read_csv("games.csv")
games.head()
# Out:
#    attendance  away_final_score away_team        date  elapsed_time  \
# 0       35055                 3       sln  2015-04-05           184
# 1       45909                 1       ana  2015-04-06           153
# 2       36969                 2       atl  2015-04-06           156
# 3       31042                 6       bal  2015-04-06           181
# 4       45549                 8       bos  2015-04-06           181
#
#         g_id  home_final_score home_team start_time    umpire_1B  \
# 0  201500001                 0       chn    7:17 PM  Mark Wegner
# 1  201500002                 4       sea    1:12 PM    Ron Kulpa
# 2  201500003                 1       mia    4:22 PM     Laz Diaz
# 3  201500004                 2       tba    3:12 PM    Ed Hickox
# 4  201500005                 0       phi    3:08 PM   Phil Cuzzi
#
#         umpire_2B        umpire_3B      umpire_HP          venue_name  \
# 0    Marty Foster  Mike Muchlinski   Mike Winters       Wrigley Field
# ...

# %%
games.wind = games.wind.str.split(" ", n = 1, expand = True)

# %%
#winds[0] = pd.to_numeric(winds[0])

# %%
#nums = winds[0]

# %%
#winds.max()

# %%
#nums.max()

# %%
games.wind=games.wind.astype("int")
means=games.groupby("venue_name").wind.mean()
means.idxmax()
# Out:
# 'AT&T Park'

# %%
ndf = pd.DataFrame(games.venue_name, games.wind)
ndf.sort_values(by=['wind'])
# Out:
#               venue_name
# wind
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# 0          Wrigley Field
# ...                  ...
# 23          Marlins Park
# 23          Marlins Park
# 23          Marlins Park
# 23          Marlins Park
# ...
